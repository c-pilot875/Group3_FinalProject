# %%
#import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import dataset
nfl_df = pd.read_csv('nfl.csv')

# %%
#show dataset

nfl_df
# Out:
#       Year                   Player   Age            School  Height  \
# 0     2009    Beanie Wells\WellCh00  20.0          Ohio St.  1.8542
# 1     2009      Will Davis\DaviWi99  22.0          Illinois  1.8796
# 2     2009  Herman Johnson\JohnHe23  24.0               LSU  2.0066
# 3     2009  Rashad Johnson\JohnRa98  23.0           Alabama  1.8034
# 4     2009      Cody Brown\BrowCo96  22.0       Connecticut  1.8796
# ...    ...                      ...   ...               ...     ...
# 3472  2019          Xavier Crawford   NaN  Central Michigan  1.8034
# 3473  2019             Jordan Brown   NaN  South Dakota St.  1.8288
# 3474  2019         Corey Ballentine   NaN          Washburn  1.8034
# 3475  2019                Ugo Amadi   NaN            Oregon  1.7526
# 3476  2019           Nasir Adderley   NaN          Delaware  1.8288
#
#           Weight  Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# ...

# %%
team_df = nfl_df['Drafted..tm.rnd.yr.'].str.split('/', expand = True)
team_df
# Out:
#                        0      1             2      3
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]

# %%
#rename drafted_df columns
# needs to be added into main DF
team_df.columns = ['Team', 'Round', 'Overall_Pick', 'Year']
team_df
# Out:
#                     Team  Round  Overall_Pick   Year
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]

# %%
team_df = team_df.dropna()
#team_df['Team'] = team_df['Team'].replace(['Washington Redskins'], 'Washington Commanders')
team_df
# Out:
#                       Team  Round  Overall_Pick   Year
# 0       Arizona Cardinals    1st     31st pick    2009
# 1       Arizona Cardinals    6th    204th pick    2009
# 2       Arizona Cardinals    5th    167th pick    2009
# 3       Arizona Cardinals    3rd     95th pick    2009
# 4       Arizona Cardinals    2nd     63rd pick    2009
# ...                    ...    ...           ...    ...
# 2249  Washington Redskins    5th    153rd pick    2019
# 2250  Washington Redskins    3rd     76th pick    2019
# 2251  Washington Redskins    4th    112th pick    2019
# 2252  Washington Redskins    1st     15th pick    2019
# 2253  Washington Redskins    6th    206th pick    2019
#
# [2254 rows x 4 columns]

# %%
team_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2254 entries, 0 to 2253
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          2254 non-null   object
#  1   Round         2254 non-null   object
#  2   Overall_Pick  2254 non-null   object
#  3   Year          2254 non-null   object
# dtypes: object(4)
# memory usage: 88.0+ KB

# %%
#team one picks
print('Washingtong Redskins Picks 2009-2019')
WSH_df = team_df[team_df['Team'].str.contains('Washington Redskins')]
WSH_df.sort_values(by = ['Year', 'Round'], ascending = [True, True])
WSH_df['Player'] = nfl_df['Player'].astype('string')

WSH_df.replace
WSH_df
# Out:
# Washingtong Redskins Picks 2009-2019
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_23390/1583918097.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WSH_df['Player'] = nfl_df['Player'].astype('string')
#                       Team  Round  Overall_Pick   Year  \
# 205   Washington Redskins    1st     13th pick    2009
# 206   Washington Redskins    7th    243rd pick    2009
# 207   Washington Redskins    7th    221st pick    2009
# 208   Washington Redskins    5th    158th pick    2009
# 209   Washington Redskins    3rd     80th pick    2009
# ...                    ...    ...           ...    ...
# 2249  Washington Redskins    5th    153rd pick    2019
# 2250  Washington Redskins    3rd     76th pick    2019
# ...

# %%
#team two picks
print('Cleveland Browns Picks 2009-2019')
CLE_df = team_df[team_df['Team'].str.contains('Cleveland Browns')]
CLE_df.sort_values(by = ['Year', 'Round'], ascending = [True, True])
CLE_df['Player'] = nfl_df['Player'].astype('string')
CLE_df
# Out:
# Cleveland Browns Picks 2009-2019
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_23390/4082157077.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CLE_df['Player'] = nfl_df['Player'].astype('string')
#                    Team  Round  Overall_Pick   Year  \
# 45    Cleveland Browns    1st     21st pick    2009
# 46    Cleveland Browns    4th    104th pick    2009
# 47    Cleveland Browns    2nd     52nd pick    2009
# 48    Cleveland Browns    6th    195th pick    2009
# 49    Cleveland Browns    2nd     50th pick    2009
# ...                 ...    ...           ...    ...
# 1993  Cleveland Browns    3rd     67th pick    2018
# 1994  Cleveland Browns    1st      1st pick    2018
# ...

# %%
#team three picks
print('New England Patriots Picks 2009-2019')
NE_df = team_df[team_df['Team'].str.contains('New England Patriots')]
NE_df.sort_values(by = ['Year', 'Round'], ascending = [True, True])
NE_df['Player'] = nfl_df['Player'].astype('string')
NE_df
# Out:
# New England Patriots Picks 2009-2019
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_23390/2739634239.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NE_df['Player'] = nfl_df['Player'].astype('string')
#                        Team  Round  Overall_Pick   Year  \
# 138   New England Patriots    2nd     34th pick    2009
# 139   New England Patriots    3rd     97th pick    2009
# 140   New England Patriots    3rd     83rd pick    2009
# 141   New England Patriots    7th    234th pick    2009
# 142   New England Patriots    2nd     41st pick    2009
# ...                     ...    ...           ...    ...
# 2207  New England Patriots    1st     32nd pick    2019
# 2208  New England Patriots    7th    252nd pick    2019
# ...

# %%
#Team four picks
print("Carolina Panthers Picks 2009-2019")
CAR_df = team_df[team_df['Team'].str.contains('Carolina Panthers')]
CAR_df.sort_values(by = ['Year', 'Round'], ascending = [True, True])
CAR_df['Player'] = nfl_df['Player'].astype('string')
CAR_df
# Out:
# Carolina Panthers Picks 2009-2019
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_23390/2201700982.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CAR_df['Player'] = nfl_df['Player'].astype('string')
#                     Team  Round  Overall_Pick   Year  \
# 25    Carolina Panthers    2nd     43rd pick    2009
# 26    Carolina Panthers    4th    128th pick    2009
# 27    Carolina Panthers    4th    111th pick    2009
# 28    Carolina Panthers    3rd     93rd pick    2009
# 29    Carolina Panthers    7th    216th pick    2009
# ...                  ...    ...           ...    ...
# 2149  Carolina Panthers    3rd    100th pick    2019
# 2150  Carolina Panthers    7th    237th pick    2019
# ...

# %%
#Team five picks
print('San Francisco 49ers Picks 2009-2019')
SF_df = team_df[team_df['Team'].str.contains('San Francisco 49ers')]
SF_df.sort_values(by = ['Year', 'Round'], ascending = [True, True])
SF_df['Player'] = nfl_df['Player'].astype('string')
SF_df
# Out:
# New England Patriots Picks 2009-2019
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_23390/2304371550.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SF_df['Player'] = nfl_df['Player'].astype('string')
#                       Team  Round  Overall_Pick   Year  \
# 180   San Francisco 49ers    1st     10th pick    2009
# 181   San Francisco 49ers    6th    184th pick    2009
# 182   San Francisco 49ers    5th    171st pick    2009
# 183   San Francisco 49ers    5th    146th pick    2009
# 184   San Francisco 49ers    7th    244th pick    2009
# ...                    ...    ...           ...    ...
# 2106  San Francisco 49ers    3rd     70th pick    2018
# 2235  San Francisco 49ers    4th    110th pick    2019
# ...
