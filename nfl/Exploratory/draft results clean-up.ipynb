# %%
#import pandas
import pandas as pd
import numpy as np

# %%
#import dataset
nfl_df = pd.read_csv('nfl.csv')

# %%
#show dataset
nfl_df
# Out:
#       Year                   Player   Age            School  Height  \
# 0     2009    Beanie Wells\WellCh00  20.0          Ohio St.  1.8542
# 1     2009      Will Davis\DaviWi99  22.0          Illinois  1.8796
# 2     2009  Herman Johnson\JohnHe23  24.0               LSU  2.0066
# 3     2009  Rashad Johnson\JohnRa98  23.0           Alabama  1.8034
# 4     2009      Cody Brown\BrowCo96  22.0       Connecticut  1.8796
# ...    ...                      ...   ...               ...     ...
# 3472  2019          Xavier Crawford   NaN  Central Michigan  1.8034
# 3473  2019             Jordan Brown   NaN  South Dakota St.  1.8288
# 3474  2019         Corey Ballentine   NaN          Washburn  1.8034
# 3475  2019                Ugo Amadi   NaN            Oregon  1.7526
# 3476  2019           Nasir Adderley   NaN          Delaware  1.8288
#
#           Weight  Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# ...

# %%
#separate Drafted..tm.rnd.yr. column
draft_df = nfl_df['Drafted..tm.rnd.yr.'].str.split('/', expand = True)
draft_df
# Out:
#                        0      1             2      3
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]

# %%
#rename drafted_df columns
# needs to be added into main DF
draft_df.columns = ['Team', 'Round', 'Overall_Pick', 'Year']
draft_df
# Out:
#                     Team  Round  Overall_Pick   Year
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]

# %%
#set column from nfl_df to variable
Player = nfl_df['Player']

# %%
#add player column from nfl_df to drafted_df
combine_df = draft_df.join(Player)
combine_df
# Out:
#                     Team  Round  Overall_Pick   Year                   Player
# 0     Arizona Cardinals    1st     31st pick    2009    Beanie Wells\WellCh00
# 1     Arizona Cardinals    6th    204th pick    2009      Will Davis\DaviWi99
# 2     Arizona Cardinals    5th    167th pick    2009  Herman Johnson\JohnHe23
# 3     Arizona Cardinals    3rd     95th pick    2009  Rashad Johnson\JohnRa98
# 4     Arizona Cardinals    2nd     63rd pick    2009      Cody Brown\BrowCo96
# ...                  ...    ...           ...    ...                      ...
# 3472                 NaN    NaN           NaN    NaN          Xavier Crawford
# 3473                 NaN    NaN           NaN    NaN             Jordan Brown
# 3474                 NaN    NaN           NaN    NaN         Corey Ballentine
# 3475                 NaN    NaN           NaN    NaN                Ugo Amadi
# 3476                 NaN    NaN           NaN    NaN           Nasir Adderley
#
# [3477 rows x 5 columns]

# %%
combine_df.loc[:,['Year', 'Player', 'Team', 'Round', 'Overall_Pick']]
# Out:
#        Year                   Player                Team  Round  Overall_Pick
# 0      2009    Beanie Wells\WellCh00  Arizona Cardinals    1st     31st pick
# 1      2009      Will Davis\DaviWi99  Arizona Cardinals    6th    204th pick
# 2      2009  Herman Johnson\JohnHe23  Arizona Cardinals    5th    167th pick
# 3      2009  Rashad Johnson\JohnRa98  Arizona Cardinals    3rd     95th pick
# 4      2009      Cody Brown\BrowCo96  Arizona Cardinals    2nd     63rd pick
# ...     ...                      ...                 ...    ...           ...
# 3472    NaN          Xavier Crawford                 NaN    NaN           NaN
# 3473    NaN             Jordan Brown                 NaN    NaN           NaN
# 3474    NaN         Corey Ballentine                 NaN    NaN           NaN
# 3475    NaN                Ugo Amadi                 NaN    NaN           NaN
# 3476    NaN           Nasir Adderley                 NaN    NaN           NaN
#
# [3477 rows x 5 columns]

# %%
# add school
combine_df['School'] = nfl_df['School']
combine_df
# Out:
#                     Team  Round  Overall_Pick   Year                   Player  \
# 0     Arizona Cardinals    1st     31st pick    2009    Beanie Wells\WellCh00
# 1     Arizona Cardinals    6th    204th pick    2009      Will Davis\DaviWi99
# 2     Arizona Cardinals    5th    167th pick    2009  Herman Johnson\JohnHe23
# 3     Arizona Cardinals    3rd     95th pick    2009  Rashad Johnson\JohnRa98
# 4     Arizona Cardinals    2nd     63rd pick    2009      Cody Brown\BrowCo96
# ...                  ...    ...           ...    ...                      ...
# 3472                 NaN    NaN           NaN    NaN          Xavier Crawford
# 3473                 NaN    NaN           NaN    NaN             Jordan Brown
# 3474                 NaN    NaN           NaN    NaN         Corey Ballentine
# 3475                 NaN    NaN           NaN    NaN                Ugo Amadi
# 3476                 NaN    NaN           NaN    NaN           Nasir Adderley
#
#                 School
# ...

# %%
#reorder updated combine_df
combine_df = combine_df.loc[:,['Year', 'Player', 'School', 'Round', 'Overall_Pick', 'Team']]
combine_df
# Out:
#        Year                   Player            School  Round  Overall_Pick  \
# 0      2009    Beanie Wells\WellCh00          Ohio St.   1st     31st pick
# 1      2009      Will Davis\DaviWi99          Illinois   6th    204th pick
# 2      2009  Herman Johnson\JohnHe23               LSU   5th    167th pick
# 3      2009  Rashad Johnson\JohnRa98           Alabama   3rd     95th pick
# 4      2009      Cody Brown\BrowCo96       Connecticut   2nd     63rd pick
# ...     ...                      ...               ...    ...           ...
# 3472    NaN          Xavier Crawford  Central Michigan    NaN           NaN
# 3473    NaN             Jordan Brown  South Dakota St.    NaN           NaN
# 3474    NaN         Corey Ballentine          Washburn    NaN           NaN
# 3475    NaN                Ugo Amadi            Oregon    NaN           NaN
# 3476    NaN           Nasir Adderley          Delaware    NaN           NaN
#
#                     Team
# 0     Arizona Cardinals
# ...

# %%
#Add drafted column from nfl_df to combine_df
combine_df['Drafted'] = nfl_df['Drafted']
combine_df
# Out:
#        Year                   Player            School  Round  Overall_Pick  \
# 0      2009    Beanie Wells\WellCh00          Ohio St.   1st     31st pick
# 1      2009      Will Davis\DaviWi99          Illinois   6th    204th pick
# 2      2009  Herman Johnson\JohnHe23               LSU   5th    167th pick
# 3      2009  Rashad Johnson\JohnRa98           Alabama   3rd     95th pick
# 4      2009      Cody Brown\BrowCo96       Connecticut   2nd     63rd pick
# ...     ...                      ...               ...    ...           ...
# 3472    NaN          Xavier Crawford  Central Michigan    NaN           NaN
# 3473    NaN             Jordan Brown  South Dakota St.    NaN           NaN
# 3474    NaN         Corey Ballentine          Washburn    NaN           NaN
# 3475    NaN                Ugo Amadi            Oregon    NaN           NaN
# 3476    NaN           Nasir Adderley          Delaware    NaN           NaN
#
#                     Team Drafted
# ...

# %%
#
players_drafted_df = combine_df.loc[combine_df['Drafted'] == 'Yes']
players_drafted_df
# Out:
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# 2249   2019  Ross Pierschbacher\PierRo00             Alabama   5th
# 2250   2019      Terry McLaurin\McLaTe00            Ohio St.   3rd
# 2251   2019          Bryce Love\LoveBr00            Stanford   4th
# 2252   2019      Dwayne Haskins\HaskDw00            Ohio St.   1st
# 2253   2019       Kelvin Harmon\HarmKe00  North Carolina St.   6th
#
#       Overall_Pick                  Team Drafted
# 0       31st pick     Arizona Cardinals      Yes
# 1      204th pick     Arizona Cardinals      Yes
# ...

# %%
#Sort drafted players df by School
players_drafted_df.sort_values(by=['School'])
# Out:
#        Year                    Player             School  Round  Overall_Pick  \
# 544    2011      Clyde Gates\GateCl00  Abilene Christian   4th    111th pick
# 40     2009    Bernard Scott\ScotBe00  Abilene Christian   6th    209th pick
# 34     2009      Johnny Knox\KnoxJo00  Abilene Christian   5th    140th pick
# 1911   2017       D.J. Jones\JoneD.01              Akron   6th    198th pick
# 798    2012     Matt McCants\McCaMa00     Ala-Birmingham   6th    201st pick
# ...     ...                       ...                ...    ...           ...
# 1288   2014  Marqueston Huff\HuffMa00            Wyoming   4th    122nd pick
# 1936   2017   Chase Roullier\RoulCh00            Wyoming   6th    199th pick
# 1356   2015     Mark Nzeocha\NzeoMa00            Wyoming   7th    236th pick
# 1855   2017     Derek Rivers\RiveDe00     Youngstown St.   3rd     83rd pick
# 1868   2017       Avery Moss\MossAv00     Youngstown St.   5th    167th pick
#
#                        Team Drafted
# ...

# %%
players_drafted_df['Sprint_40yd'] = nfl_df['Sprint_40yd']
players_drafted_df
# Out:
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_96837/2130612098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_drafted_df['Sprint_40yd'] = nfl_df['Sprint_40yd']
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# 2249   2019  Ross Pierschbacher\PierRo00             Alabama   5th
# ...

# %%
players_drafted_df['Vertical_Jump'] = nfl_df['Vertical_Jump']
players_drafted_df
# Out:
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_96837/1751073243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_drafted_df['Vertical_Jump'] = nfl_df['Vertical_Jump']
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# ...

# %%
players_drafted_df['Bench_Press_Reps'] = nfl_df['Bench_Press_Reps']
players_drafted_df
# Out:
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_96837/1088619391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_drafted_df['Bench_Press_Reps'] = nfl_df['Bench_Press_Reps']
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# ...

# %%
players_drafted_df['Broad_Jump'] = nfl_df['Broad_Jump']
players_drafted_df
# Out:
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_96837/2568882472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_drafted_df['Broad_Jump'] = nfl_df['Broad_Jump']
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# 2249   2019  Ross Pierschbacher\PierRo00             Alabama   5th
# ...

# %%
players_drafted_df['Agility_3cone'] = nfl_df['Agility_3cone']
players_drafted_df
# Out:
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_96837/191875169.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_drafted_df['Agility_3cone'] = nfl_df['Agility_3cone']
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# 2249   2019  Ross Pierschbacher\PierRo00             Alabama   5th
# ...

# %%
players_drafted_df['Shuttle'] = nfl_df['Shuttle']
players_drafted_df
# Out:
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_96837/1564135052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_drafted_df['Shuttle'] = nfl_df['Shuttle']
#        Year                       Player              School  Round  \
# 0      2009        Beanie Wells\WellCh00            Ohio St.   1st
# 1      2009          Will Davis\DaviWi99            Illinois   6th
# 2      2009      Herman Johnson\JohnHe23                 LSU   5th
# 3      2009      Rashad Johnson\JohnRa98             Alabama   3rd
# 4      2009          Cody Brown\BrowCo96         Connecticut   2nd
# ...     ...                          ...                 ...    ...
# 2249   2019  Ross Pierschbacher\PierRo00             Alabama   5th
# ...

# %%
#Count for each school for drafted players
players_drafted_df['School'].value_counts()
# Out:
# Alabama               76
# Ohio St.              62
# LSU                   61
# Florida               58
# USC                   54
#                       ..
# Bloomsburg             1
# Saginaw Valley St.     1
# Hillsdale              1
# Presbyterian           1
# Arizona State          1
# Name: School, Length: 205, dtype: int64

# %%
#add drafted result column to undrafted players df
players_undrafted_df = combine_df.loc[combine_df['Drafted'] == 'No']
players_undrafted_df
# Out:
#      Year                       Player            School Round Overall_Pick  \
# 2254  NaN   Jahi Word-Daniels\WordJa99      Georgia Tech   NaN          NaN
# 2255  NaN  John Parker Wilson\WilsJo01           Alabama   NaN          NaN
# 2256  NaN      Edwin Williams\WillEd02          Maryland   NaN          NaN
# 2257  NaN          Drew Willy\WillDr00           Buffalo   NaN          NaN
# 2258  NaN        Derek Walker\WalkDe98          Illinois   NaN          NaN
# ...   ...                          ...               ...   ...          ...
# 3472  NaN              Xavier Crawford  Central Michigan   NaN          NaN
# 3473  NaN                 Jordan Brown  South Dakota St.   NaN          NaN
# 3474  NaN             Corey Ballentine          Washburn   NaN          NaN
# 3475  NaN                    Ugo Amadi            Oregon   NaN          NaN
# 3476  NaN               Nasir Adderley          Delaware   NaN          NaN
#
#      Team Drafted
# 2254  NaN      No
# ...

# %%
#sort undrafted players by school
players_undrafted_df.sort_values(by=['School'])
# Out:
#      Year                    Player          School Round Overall_Pick Team  \
# 3179  NaN  Jalen Robinette\RobiJa02       Air Force   NaN          NaN  NaN
# 3204  NaN      Jerome Lane\LaneJe01           Akron   NaN          NaN  NaN
# 2876  NaN   Adrian Hubbard\HubbAd00         Alabama   NaN          NaN  NaN
# 3355  NaN              Dashawn Hand         Alabama   NaN          NaN  NaN
# 3029  NaN               Chris Jones         Alabama   NaN          NaN  NaN
# ...   ...                       ...             ...   ...          ...  ...
# 3384  NaN   Andrew Wingard\WingAn00         Wyoming   NaN          NaN  NaN
# 2661  NaN              Patrick Witt            Yale   NaN          NaN  NaN
# 3009  NaN               Tyler Varga            Yale   NaN          NaN  NaN
# 2746  NaN       Lamar Mady\MadyLa00  Youngstown St.   NaN          NaN  NaN
# 2401  NaN     Donald Jones\JoneDo00  Youngstown St.   NaN          NaN  NaN
#
#      Drafted
# 3179      No
# 3204      No
# ...

# %%
#Count of each school for undrafted players
players_undrafted_df['School'].value_counts()
# Out:
# LSU              34
# USC              25
# Alabama          25
# Michigan St.     22
# Florida St.      21
#                  ..
# Lehigh            1
# Arkansas St.      1
# Louisiana St      1
# Southern Utah     1
# Delaware          1
# Name: School, Length: 206, dtype: int64

# %%
#Delete unnecessary columns from undrafted players df
del players_undrafted_df['Round']
del players_undrafted_df['Overall_Pick']
del players_undrafted_df['Team']

# %%
players_undrafted_df
# Out:
#      Year                       Player            School Drafted
# 2254  NaN   Jahi Word-Daniels\WordJa99      Georgia Tech      No
# 2255  NaN  John Parker Wilson\WilsJo01           Alabama      No
# 2256  NaN      Edwin Williams\WillEd02          Maryland      No
# 2257  NaN          Drew Willy\WillDr00           Buffalo      No
# 2258  NaN        Derek Walker\WalkDe98          Illinois      No
# ...   ...                          ...               ...     ...
# 3472  NaN              Xavier Crawford  Central Michigan      No
# 3473  NaN                 Jordan Brown  South Dakota St.      No
# 3474  NaN             Corey Ballentine          Washburn      No
# 3475  NaN                    Ugo Amadi            Oregon      No
# 3476  NaN               Nasir Adderley          Delaware      No
#
# [1223 rows x 4 columns]

# %%
# export CSVs
players_drafted_df.to_csv('Drafted_Players')
players_undrafted_df.to_csv('Undrafted_players')

# %%
draft_df
# Out:
#                     Team  Round  Overall_Pick   Year
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]
