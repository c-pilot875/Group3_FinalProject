# %%
#importing pandas
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
#importing nfl_csv
nfl_df = pd.read_csv('nfl.csv')

nfl_df
# Out:
#       Year                   Player   Age            School  Height  \
# 0     2009    Beanie Wells\WellCh00  20.0          Ohio St.  1.8542
# 1     2009      Will Davis\DaviWi99  22.0          Illinois  1.8796
# 2     2009  Herman Johnson\JohnHe23  24.0               LSU  2.0066
# 3     2009  Rashad Johnson\JohnRa98  23.0           Alabama  1.8034
# 4     2009      Cody Brown\BrowCo96  22.0       Connecticut  1.8796
# ...    ...                      ...   ...               ...     ...
# 3472  2019          Xavier Crawford   NaN  Central Michigan  1.8034
# 3473  2019             Jordan Brown   NaN  South Dakota St.  1.8288
# 3474  2019         Corey Ballentine   NaN          Washburn  1.8034
# 3475  2019                Ugo Amadi   NaN            Oregon  1.7526
# 3476  2019           Nasir Adderley   NaN          Delaware  1.8288
#
#           Weight  Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# ...

# %%
draft_df = nfl_df['Drafted..tm.rnd.yr.'].str.split('/', expand = True)
draft_df
# Out:
#                        0      1             2      3
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]

# %%
#rename drafted_df columns
# needs to be added into main DF
draft_df.columns = ['Team', 'Round', 'Overall_Pick', 'Year']
draft_df
# Out:
#                     Team  Round  Overall_Pick   Year
# 0     Arizona Cardinals    1st     31st pick    2009
# 1     Arizona Cardinals    6th    204th pick    2009
# 2     Arizona Cardinals    5th    167th pick    2009
# 3     Arizona Cardinals    3rd     95th pick    2009
# 4     Arizona Cardinals    2nd     63rd pick    2009
# ...                  ...    ...           ...    ...
# 3472                 NaN    NaN           NaN    NaN
# 3473                 NaN    NaN           NaN    NaN
# 3474                 NaN    NaN           NaN    NaN
# 3475                 NaN    NaN           NaN    NaN
# 3476                 NaN    NaN           NaN    NaN
#
# [3477 rows x 4 columns]

# %%
#set column from nfl_df to variable
Player = nfl_df['Player']

# %%
#add player column from nfl_df to drafted_df
draft_df = draft_df.join(Player)
draft_df
# Out:
#                     Team  Round  Overall_Pick   Year                   Player
# 0     Arizona Cardinals    1st     31st pick    2009    Beanie Wells\WellCh00
# 1     Arizona Cardinals    6th    204th pick    2009      Will Davis\DaviWi99
# 2     Arizona Cardinals    5th    167th pick    2009  Herman Johnson\JohnHe23
# 3     Arizona Cardinals    3rd     95th pick    2009  Rashad Johnson\JohnRa98
# 4     Arizona Cardinals    2nd     63rd pick    2009      Cody Brown\BrowCo96
# ...                  ...    ...           ...    ...                      ...
# 3472                 NaN    NaN           NaN    NaN          Xavier Crawford
# 3473                 NaN    NaN           NaN    NaN             Jordan Brown
# 3474                 NaN    NaN           NaN    NaN         Corey Ballentine
# 3475                 NaN    NaN           NaN    NaN                Ugo Amadi
# 3476                 NaN    NaN           NaN    NaN           Nasir Adderley
#
# [3477 rows x 5 columns]

# %%
#drop team column
draft_df.drop(columns = ['Team'], inplace = True)
draft_df
# Out:
#       Round  Overall_Pick   Year                   Player
# 0      1st     31st pick    2009    Beanie Wells\WellCh00
# 1      6th    204th pick    2009      Will Davis\DaviWi99
# 2      5th    167th pick    2009  Herman Johnson\JohnHe23
# 3      3rd     95th pick    2009  Rashad Johnson\JohnRa98
# 4      2nd     63rd pick    2009      Cody Brown\BrowCo96
# ...     ...           ...    ...                      ...
# 3472    NaN           NaN    NaN          Xavier Crawford
# 3473    NaN           NaN    NaN             Jordan Brown
# 3474    NaN           NaN    NaN         Corey Ballentine
# 3475    NaN           NaN    NaN                Ugo Amadi
# 3476    NaN           NaN    NaN           Nasir Adderley
#
# [3477 rows x 4 columns]

# %%
#adding columns to draft_df
draft_df['Sprint_40yd'] = nfl_df['Sprint_40yd']
draft_df['Vertical_Jump'] = nfl_df['Vertical_Jump']
draft_df['Bench_Press_Reps'] = nfl_df['Bench_Press_Reps']
draft_df['Broad_Jump'] = nfl_df['Broad_Jump']
draft_df['Agility_3cone'] = nfl_df['Agility_3cone']
draft_df['Shuttle'] = nfl_df['Shuttle']
draft_df['Position_Type'] = nfl_df['Position_Type']
draft_df['Drafted'] = nfl_df['Drafted']

# %%
draft_df.head()
# Out:
#    Round  Overall_Pick   Year                   Player  Sprint_40yd  \
# 0   1st     31st pick    2009    Beanie Wells\WellCh00         4.38
# 1   6th    204th pick    2009      Will Davis\DaviWi99         4.84
# 2   5th    167th pick    2009  Herman Johnson\JohnHe23         5.50
# 3   3rd     95th pick    2009  Rashad Johnson\JohnRa98         4.49
# 4   2nd     63rd pick    2009      Cody Brown\BrowCo96         4.76
#
#    Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle  \
# 0          85.09              25.0      325.12            NaN      NaN
# 1          83.82              27.0      292.10           7.38     4.45
# 2            NaN              21.0         NaN            NaN      NaN
# 3          93.98              15.0      304.80           7.09     4.23
# 4          92.71              26.0      304.80           7.10     4.40
#
#        Position_Type Drafted
# 0    backs_receivers     Yes
# 1  defensive_lineman     Yes
# 2  offensive_lineman     Yes
# ...

# %%
#reorder columns
combine_df = draft_df.loc[:,['Year', 'Player', 'Position_Type', 'Round', 'Overall_Pick', 'Sprint_40yd', 'Vertical_Jump', 'Bench_Press_Reps', 'Broad_Jump', 'Agility_3cone', 'Shuttle', 'Drafted']]

# %%
#stats for drafted players
players_drafted_df = combine_df.loc[draft_df['Drafted'] == 'Yes']
players_drafted_df
# Out:
#        Year                       Player      Position_Type  Round  \
# 0      2009        Beanie Wells\WellCh00    backs_receivers   1st
# 1      2009          Will Davis\DaviWi99  defensive_lineman   6th
# 2      2009      Herman Johnson\JohnHe23  offensive_lineman   5th
# 3      2009      Rashad Johnson\JohnRa98     defensive_back   3rd
# 4      2009          Cody Brown\BrowCo96        line_backer   2nd
# ...     ...                          ...                ...    ...
# 2249   2019  Ross Pierschbacher\PierRo00  offensive_lineman   5th
# 2250   2019      Terry McLaurin\McLaTe00    backs_receivers   3rd
# 2251   2019          Bryce Love\LoveBr00    backs_receivers   4th
# 2252   2019      Dwayne Haskins\HaskDw00    backs_receivers   1st
# 2253   2019       Kelvin Harmon\HarmKe00    backs_receivers   6th
#
#       Overall_Pick  Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# 0       31st pick          4.38          85.09              25.0      325.12
# ...

# %%
#Remove unnecessary columns
del players_drafted_df['Drafted']
del players_drafted_df['Round']
del players_drafted_df['Overall_Pick']
players_drafted_df
# Out:
#        Year                       Player      Position_Type  Sprint_40yd  \
# 0      2009        Beanie Wells\WellCh00    backs_receivers         4.38
# 1      2009          Will Davis\DaviWi99  defensive_lineman         4.84
# 2      2009      Herman Johnson\JohnHe23  offensive_lineman         5.50
# 3      2009      Rashad Johnson\JohnRa98     defensive_back         4.49
# 4      2009          Cody Brown\BrowCo96        line_backer         4.76
# ...     ...                          ...                ...          ...
# 2249   2019  Ross Pierschbacher\PierRo00  offensive_lineman         5.20
# 2250   2019      Terry McLaurin\McLaTe00    backs_receivers         4.35
# 2251   2019          Bryce Love\LoveBr00    backs_receivers          NaN
# 2252   2019      Dwayne Haskins\HaskDw00    backs_receivers         5.04
# 2253   2019       Kelvin Harmon\HarmKe00    backs_receivers         4.60
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
#need to create DF for all positions
players_drafted_df['Position_Type'].value_counts()
# Out:
# backs_receivers       770
# defensive_back        445
# offensive_lineman     366
# defensive_lineman     364
# line_backer           273
# kicking_specialist     32
# other_special           4
# Name: Position_Type, dtype: int64

# %%
#creating backs and receivers dataframe
backs_receivers_df = players_drafted_df[players_drafted_df['Position_Type'] == 'backs_receivers']
backs_receivers_df
# Out:
#        Year                   Player    Position_Type  Sprint_40yd  \
# 0      2009    Beanie Wells\WellCh00  backs_receivers         4.38
# 13     2009      Davon Drew\DrewDa00  backs_receivers         4.78
# 17     2009  Cedric Peerman\PeerCe00  backs_receivers         4.34
# 19     2009    Shawn Nelson\NelsSh00  backs_receivers         4.52
# 26     2009  Tony Fiammetta\FiamTo00  backs_receivers         4.58
# ...     ...                      ...              ...          ...
# 2248   2019      A.J. Brown\BrowAJ00  backs_receivers         4.49
# 2250   2019  Terry McLaurin\McLaTe00  backs_receivers         4.35
# 2251   2019      Bryce Love\LoveBr00  backs_receivers          NaN
# 2252   2019  Dwayne Haskins\HaskDw00  backs_receivers         5.04
# 2253   2019   Kelvin Harmon\HarmKe00  backs_receivers         4.60
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 0             85.09              25.0      325.12            NaN      NaN
# ...

# %%
#export dataframe to csv file
backs_receivers_df.to_csv('Backs_Receivers stats')

# %%
#describing backs_receivers_df
backs_receivers_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   733.000000     653.000000        524.000000  637.000000
# mean      4.588568      87.458851         17.887405  301.458524
# std       0.176530       8.718910          5.317879   17.431871
# min       4.220000      60.960000          3.000000  243.840000
# 25%       4.460000      81.280000         14.000000  289.560000
# 50%       4.550000      87.630000         18.000000  302.260000
# 75%       4.690000      92.710000         21.000000  312.420000
# max       5.370000     114.300000         36.000000  355.600000
#
#        Agility_3cone     Shuttle
# count     512.000000  533.000000
# mean        7.008730    4.272720
# std         0.206636    0.151822
# min         6.500000    3.810000
# 25%         6.877500    4.160000
# 50%         7.000000    4.270000
# 75%         7.132500    4.380000
# max         7.650000    4.750000

# %%
#creating defensive backs df
defensive_back_df = players_drafted_df[players_drafted_df['Position_Type'] == 'defensive_back']
defensive_back_df
# Out:
#        Year                   Player   Position_Type  Sprint_40yd  \
# 3      2009  Rashad Johnson\JohnRa98  defensive_back         4.49
# 9      2009     Chris Owens\OwenCh99  defensive_back         4.44
# 10     2009   William Moore\MoorWi99  defensive_back         4.49
# 15     2009  Lardarius Webb\WebbLa99  defensive_back         4.35
# 21     2009     Jairus Byrd\ByrdJa99  defensive_back         4.68
# ...     ...                      ...             ...          ...
# 2240   2019  Marquise Blair\BlaiMa01  defensive_back         4.48
# 2243   2019      Jamel Dean\DeanJa00  defensive_back         4.30
# 2244   2019    Sean Bunting\BuntSe00  defensive_back         4.42
# 2246   2019    Mike Edwards\EdwaMi01  defensive_back          NaN
# 2247   2019    Amani Hooker\HookAm00  defensive_back         4.48
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 3             93.98              15.0      304.80           7.09     4.23
# ...

# %%
# export to CSV
defensive_back_df.to_csv('Defensive_backs stats')

# %%
# describing defensive back stats
defensive_back_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   423.000000     363.000000        363.000000  369.000000
# mean      4.495154      91.303554         15.818182  310.767967
# std       0.086298       7.160851          4.351922   14.941375
# min       4.280000      74.930000          2.000000  274.320000
# 25%       4.430000      86.360000         13.000000  299.720000
# 50%       4.500000      90.170000         16.000000  309.880000
# 75%       4.550000      95.885000         18.000000  320.040000
# max       4.750000     114.300000         29.000000  373.380000
#
#        Agility_3cone     Shuttle
# count     281.000000  288.000000
# mean        6.913559    4.170556
# std         0.199532    0.134829
# min         6.440000    3.820000
# 25%         6.780000    4.070000
# 50%         6.900000    4.170000
# 75%         7.040000    4.270000
# max         7.550000    4.540000

# %%
#creating offensive lineman df
ol_df = players_drafted_df[players_drafted_df['Position_Type'] == 'offensive_lineman']
ol_df
# Out:
#        Year                       Player      Position_Type  Sprint_40yd  \
# 2      2009      Herman Johnson\JohnHe23  offensive_lineman         5.50
# 5      2009     Trevor Canfield\CanfTr20  offensive_lineman         5.28
# 7      2009    Garrett Reynolds\ReynGa20  offensive_lineman         5.32
# 12     2009        Michael Oher\OherMi20  offensive_lineman         5.16
# 20     2009        Andy Levitre\LeviAn20  offensive_lineman         5.33
# ...     ...                          ...                ...          ...
# 2209   2019       Yodny Cajuste\CajuYo00  offensive_lineman          NaN
# 2220   2019         Chuma Edoga\EdogCh00  offensive_lineman         5.19
# 2229   2019       Andre Dillard\DillAn00  offensive_lineman         4.96
# 2233   2019         Derwin Gray\GrayDe01  offensive_lineman         5.26
# 2249   2019  Ross Pierschbacher\PierRo00  offensive_lineman         5.20
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
# describe
ol_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   354.000000     296.000000        303.000000  290.000000
# mean      5.225226      71.081385         25.498350  260.919310
# std       0.164854       7.359661          5.253743   16.772714
# min       4.710000      49.530000          9.000000  208.280000
# 25%       5.140000      66.040000         22.000000  248.920000
# 50%       5.220000      71.120000         25.000000  259.080000
# 75%       5.327500      76.200000         29.000000  274.320000
# max       5.850000      90.170000         45.000000  307.340000
#
#        Agility_3cone     Shuttle
# count     278.000000  287.000000
# mean        7.766367    4.734843
# std         0.269996    0.182254
# min         7.060000    4.140000
# 25%         7.580000    4.620000
# 50%         7.770000    4.720000
# 75%         7.940000    4.865000
# max         8.420000    5.380000

# %%
# exporting
ol_df.to_csv('Offensive_Lineman Stats')

# %%
#creating defensive lineman df
dl_df = players_drafted_df[players_drafted_df['Position_Type'] == 'defensive_lineman']
dl_df
# Out:
#        Year                     Player      Position_Type  Sprint_40yd  \
# 1      2009        Will Davis\DaviWi99  defensive_lineman         4.84
# 6      2009       Peria Jerry\JerrPe99  defensive_lineman         4.98
# 8      2009  Lawrence Sidbury\SidbLa99  defensive_lineman         4.53
# 11     2009      Vance Walker\WalkVa99  defensive_lineman         5.32
# 16     2009       Paul Kruger\KrugPa99  defensive_lineman         4.79
# ...     ...                        ...                ...          ...
# 2098   2018    Joshua Frazier\FrazJo00  defensive_lineman          NaN
# 2105   2018  Kentavius Street\StreKe00  defensive_lineman         4.87
# 2112   2018     Rasheem Green\GreeRa01  defensive_lineman         4.73
# 2114   2018          Vita Vea\VeaxVi00  defensive_lineman         5.10
# 2123   2018        Tim Settle\SettTi00  defensive_lineman         5.37
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
# describing
dl_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   354.000000     298.000000        287.000000  287.000000
# mean      4.937260      79.528423         26.362369  281.364739
# std       0.204058       9.083720          5.711084   21.396242
# min       4.530000      52.070000         12.000000  223.520000
# 25%       4.800000      73.660000         22.000000  266.700000
# 50%       4.920000      80.010000         26.000000  281.940000
# 75%       5.060000      85.090000         30.000000  297.180000
# max       5.710000     106.680000         49.000000  350.520000
#
#        Agility_3cone     Shuttle
# count     264.000000  266.000000
# mean        7.460189    4.539135
# std         0.321417    0.192665
# min         6.780000    4.000000
# 25%         7.210000    4.400000
# 50%         7.440000    4.530000
# 75%         7.672500    4.677500
# max         8.290000    5.060000

# %%
#exporting
dl_df.to_csv('Defensive_Lineman Stats')

# %%
#creating linebacker df
LB_df = players_drafted_df[players_drafted_df['Position_Type'] == 'line_backer']
LB_df
# Out:
#        Year                        Player Position_Type  Sprint_40yd  \
# 4      2009           Cody Brown\BrowCo96   line_backer         4.76
# 14     2009       Jason Phillips\PhilJa99   line_backer         4.60
# 24     2009           Nic Harris\HarrNi99   line_backer         4.83
# 33     2009                Marcus Freeman   line_backer         4.51
# 43     2009         Rey Maualuga\MauaRe99   line_backer         4.91
# ...     ...                           ...           ...          ...
# 2089   2018         Azeem Victor\VictAz00   line_backer         4.72
# 2106   2018          Fred Warner\WarnFr00   line_backer         4.64
# 2109   2018      Shaquem Griffin\GrifSh01   line_backer         4.38
# 2119   2018           Jack Cichy\CichJa00   line_backer          NaN
# 2126   2018  Shaun dion Hamilton\DionSh00   line_backer          NaN
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
# describe
LB_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   264.000000     226.000000        225.000000  233.000000
# mean      4.680795      87.315310         22.733333  300.134249
# std       0.111197       7.600277          4.483103   16.020864
# min       4.380000      68.580000         11.000000  210.820000
# 25%       4.610000      81.280000         20.000000  289.560000
# 50%       4.670000      86.360000         23.000000  299.720000
# 75%       4.750000      92.710000         25.000000  309.880000
# max       5.050000     107.950000         36.000000  353.060000
#
#        Agility_3cone     Shuttle
# count     177.000000  182.000000
# mean        7.089492    4.306648
# std         0.204679    0.137227
# min         6.640000    3.960000
# 25%         6.950000    4.210000
# 50%         7.080000    4.300000
# 75%         7.220000    4.390000
# max         7.660000    4.630000

# %%
#exporting
LB_df.to_csv('Linebacker Stats')

# %%
#creating kicking specialist df
kicker_df = players_drafted_df[players_drafted_df['Position_Type'] == 'kicking_specialist']
kicker_df.head(10)
# Out:
#       Year                    Player       Position_Type  Sprint_40yd  \
# 44    2009      Kevin Huber\HubeKe20  kicking_specialist         4.87
# 59    2009    David Buehler\BuehDa44  kicking_specialist         4.57
# 147   2009  Thomas Morstead\MorsTh00  kicking_specialist         4.83
# 341   2010     Zoltan Mesko\MeskZo99  kicking_specialist         4.79
# 356   2010       Matt Dodge\DodgMa99  kicking_specialist          NaN
# 412   2010              Brent Bowden  kicking_specialist         4.80
# 434   2011      Matt Bosher\BoshMa00  kicking_specialist         4.78
# 595   2011      Alex Henery\HeneAl00  kicking_specialist         4.87
# 673   2012     Brad Nortman\NortBr00  kicking_specialist         4.78
# 727   2012    Randy Bullock\BullRa00  kicking_specialist          NaN
#
#      Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 44             NaN               NaN         NaN            NaN      NaN
# ...

# %%
#describe
kicker_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count    23.000000       5.000000          5.000000    5.000000
# mean      4.829565      81.280000         18.200000  296.672000
# std       0.134923       3.592102          6.685806    5.506589
# min       4.570000      77.470000          8.000000  289.560000
# 25%       4.775000      77.470000         16.000000  294.640000
# 50%       4.820000      82.550000         19.000000  297.180000
# 75%       4.885000      83.820000         23.000000  297.180000
# max       5.180000      85.090000         25.000000  304.800000
#
#        Agility_3cone  Shuttle
# count           1.00     1.00
# mean            7.28     4.41
# std              NaN      NaN
# min             7.28     4.41
# 25%             7.28     4.41
# 50%             7.28     4.41
# 75%             7.28     4.41
# max             7.28     4.41

# %%
#export
kicker_df.to_csv('Kicker Stats')

# %%
# creating other specials df
other_specialist_df = players_drafted_df[players_drafted_df['Position_Type'] == 'other_special']
other_specialist_df
# Out:
#        Year                 Player  Position_Type  Sprint_40yd  Vertical_Jump  \
# 145    2009   Jake Ingram\IngrJa20  other_special         4.90            NaN
# 1434   2015   Joe Cardona\CardJo00  other_special         4.91          83.82
# 1583   2016  Jimmy Landes\LandJi00  other_special         4.95          69.85
# 1899   2017   Colin Holba\HolbCo00  other_special         5.19          71.12
#
#       Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 145               15.0         NaN            NaN      NaN
# 1434              30.0         NaN            NaN      NaN
# 1583               NaN       279.4           7.05     4.38
# 1899               NaN       292.1            NaN      NaN

# %%
#describe
other_specialist_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count     4.000000       3.000000          2.000000    2.000000
# mean      4.987500      74.930000         22.500000  285.750000
# std       0.136717       7.725108         10.606602    8.980256
# min       4.900000      69.850000         15.000000  279.400000
# 25%       4.907500      70.485000         18.750000  282.575000
# 50%       4.930000      71.120000         22.500000  285.750000
# 75%       5.010000      77.470000         26.250000  288.925000
# max       5.190000      83.820000         30.000000  292.100000
#
#        Agility_3cone  Shuttle
# count           1.00     1.00
# mean            7.05     4.38
# std              NaN      NaN
# min             7.05     4.38
# 25%             7.05     4.38
# 50%             7.05     4.38
# 75%             7.05     4.38
# max             7.05     4.38

# %%
#export
other_specialist_df.to_csv('Other_Specialist Stats')

# %%
#stats for undrafted players
players_undrafted_df = combine_df.loc[draft_df['Drafted'] == 'No']
players_undrafted_df
# Out:
#      Year                       Player      Position_Type Round Overall_Pick  \
# 2254  NaN   Jahi Word-Daniels\WordJa99     defensive_back   NaN          NaN
# 2255  NaN  John Parker Wilson\WilsJo01    backs_receivers   NaN          NaN
# 2256  NaN      Edwin Williams\WillEd02  offensive_lineman   NaN          NaN
# 2257  NaN          Drew Willy\WillDr00    backs_receivers   NaN          NaN
# 2258  NaN        Derek Walker\WalkDe98  defensive_lineman   NaN          NaN
# ...   ...                          ...                ...   ...          ...
# 3472  NaN              Xavier Crawford     defensive_back   NaN          NaN
# 3473  NaN                 Jordan Brown     defensive_back   NaN          NaN
# 3474  NaN             Corey Ballentine     defensive_back   NaN          NaN
# 3475  NaN                    Ugo Amadi     defensive_back   NaN          NaN
# 3476  NaN               Nasir Adderley     defensive_back   NaN          NaN
#
# ...

# %%
del players_undrafted_df['Drafted']
del players_undrafted_df['Round']
del players_undrafted_df['Overall_Pick']
players_undrafted_df
# Out:
#      Year                       Player      Position_Type  Sprint_40yd  \
# 2254  NaN   Jahi Word-Daniels\WordJa99     defensive_back         4.59
# 2255  NaN  John Parker Wilson\WilsJo01    backs_receivers         4.75
# 2256  NaN      Edwin Williams\WillEd02  offensive_lineman         5.40
# 2257  NaN          Drew Willy\WillDr00    backs_receivers         4.90
# 2258  NaN        Derek Walker\WalkDe98  defensive_lineman         4.98
# ...   ...                          ...                ...          ...
# 3472  NaN              Xavier Crawford     defensive_back         4.48
# 3473  NaN                 Jordan Brown     defensive_back         4.51
# 3474  NaN             Corey Ballentine     defensive_back         4.47
# 3475  NaN                    Ugo Amadi     defensive_back         4.51
# 3476  NaN               Nasir Adderley     defensive_back          NaN
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
#creating backs and receivers dataframe - undrafted
undrafted_backs_receivers_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'backs_receivers']
undrafted_backs_receivers_df
# Out:
#      Year                       Player    Position_Type  Sprint_40yd  \
# 2255  NaN  John Parker Wilson\WilsJo01  backs_receivers         4.75
# 2257  NaN          Drew Willy\WillDr00  backs_receivers         4.90
# 2260  NaN       Tyrell Sutton\SuttTy00  backs_receivers         4.64
# 2262  NaN         Kory Sperry\SperKo00  backs_receivers         4.69
# 2263  NaN         Kory Sheets\SheeKo00  backs_receivers         4.39
# ...   ...                          ...              ...          ...
# 3459  NaN                  Alex Wesley  backs_receivers         4.45
# 3462  NaN                 Easton Stick  backs_receivers         4.62
# 3463  NaN                  Benny Snell  backs_receivers         4.66
# 3470  NaN                 Ashton Dulin  backs_receivers         4.43
# 3471  NaN                  Keelan Doss  backs_receivers          NaN
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
undrafted_backs_receivers_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   465.000000     411.000000        340.000000  403.000000
# mean      4.648581      85.253771         16.602941  295.894243
# std       0.163843       8.315222          5.013079   16.331259
# min       4.340000      64.770000          4.000000  248.920000
# 25%       4.530000      80.010000         13.000000  284.480000
# 50%       4.620000      85.090000         16.000000  297.180000
# 75%       4.750000      91.440000         20.000000  304.800000
# max       5.260000     110.490000         35.000000  358.140000
#
#        Agility_3cone     Shuttle
# count     327.000000  338.000000
# mean        7.071988    4.318077
# std         0.239014    0.159091
# min         6.420000    3.900000
# 25%         6.900000    4.200000
# 50%         7.080000    4.320000
# 75%         7.220000    4.440000
# max         7.930000    4.690000

# %%
undrafted_backs_receivers_df.to_csv('Undrafted Backs and Receivers')

# %%
#creating defensive backs df - undrafted
undrafted_defensive_back_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'defensive_back']
undrafted_defensive_back_df
# Out:
#      Year                      Player   Position_Type  Sprint_40yd  \
# 2254  NaN  Jahi Word-Daniels\WordJa99  defensive_back         4.59
# 2261  NaN      C.J. Spillman\SpilCJ99  defensive_back         4.45
# 2264  NaN    Lydell Sargeant\SargLy99  defensive_back         4.48
# 2267  NaN     Wopamo Osaisai\OsaiWo99  defensive_back         4.44
# 2281  NaN       D.J. Johnson\JohnDo99  defensive_back         4.50
# ...   ...                         ...             ...          ...
# 3472  NaN             Xavier Crawford  defensive_back         4.48
# 3473  NaN                Jordan Brown  defensive_back         4.51
# 3474  NaN            Corey Ballentine  defensive_back         4.47
# 3475  NaN                   Ugo Amadi  defensive_back         4.51
# 3476  NaN              Nasir Adderley  defensive_back          NaN
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 2254          90.17              24.0      309.88            NaN      NaN
# ...

# %%
# describing defensive back stats
undrafted_defensive_back_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   199.000000     179.000000        168.000000  176.000000
# mean      4.573266      88.254358         14.714286  304.828864
# std       0.098570       6.750302          4.275180   12.146524
# min       4.290000      71.120000          4.000000  274.320000
# 25%       4.510000      83.820000         12.000000  297.180000
# 50%       4.580000      87.630000         15.000000  304.800000
# 75%       4.640000      92.710000         17.250000  312.420000
# max       4.830000     111.760000         28.000000  342.900000
#
#        Agility_3cone     Shuttle
# count     126.000000  135.000000
# mean        6.959365    4.214963
# std         0.198683    0.130840
# min         6.280000    3.940000
# 25%         6.832500    4.150000
# 50%         6.965000    4.210000
# 75%         7.080000    4.290000
# max         7.450000    4.620000

# %%
undrafted_defensive_back_df.to_csv('Undrafted Defensive Back Stats')

# %%
#creating offensive lineman df - undrafted
undrafted_ol_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'offensive_lineman']
undrafted_ol_df
# Out:
#      Year                   Player      Position_Type  Sprint_40yd  \
# 2256  NaN  Edwin Williams\WillEd02  offensive_lineman         5.40
# 2259  NaN     Jose Valdez\ValdJo00  offensive_lineman         5.16
# 2273  NaN      Ryan McKee\McKeRy00  offensive_lineman         5.03
# 2291  NaN    Ramon Foster\FostRa21  offensive_lineman         5.57
# 2293  NaN      Ray Feinga\FeinRa20  offensive_lineman         5.32
# ...   ...                      ...                ...          ...
# 3464  NaN            Max Scharping  offensive_lineman          NaN
# 3465  NaN             Trey Pipkins  offensive_lineman         5.12
# 3466  NaN             Joshua Miles  offensive_lineman         5.32
# 3467  NaN            Devon Johnson  offensive_lineman         5.16
# 3468  NaN             Tytus Howard  offensive_lineman         5.05
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 2256          72.39              22.0      251.46           8.15     4.98
# ...

# %%
undrafted_ol_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   175.000000     147.000000        153.000000  143.000000
# mean      5.306400      67.655578         24.431373  253.680280
# std       0.189361       8.098695          5.023320   18.589175
# min       4.810000      44.450000         12.000000  198.120000
# 25%       5.185000      62.230000         21.000000  240.030000
# 50%       5.310000      67.310000         24.000000  256.540000
# 75%       5.420000      72.390000         27.000000  266.700000
# max       6.000000      91.440000         36.000000  289.560000
#
#        Agility_3cone     Shuttle
# count     132.000000  138.000000
# mean        7.934318    4.844203
# std         0.307005    0.211932
# min         7.300000    4.270000
# 25%         7.727500    4.700000
# 50%         7.910000    4.830000
# 75%         8.092500    4.977500
# max         9.040000    5.560000

# %%
undrafted_ol_df.to_csv('Undrafted Offensive Lineman stats')

# %%
#creating defensive lineman df - undrafted
undrafted_dl_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'defensive_lineman']
undrafted_dl_df
# Out:
#      Year                    Player      Position_Type  Sprint_40yd  \
# 2258  NaN     Derek Walker\WalkDe98  defensive_lineman         4.98
# 2266  NaN      Zach Potter\PottZa99  defensive_lineman         4.90
# 2272  NaN  Khalif Mitchell\MitcKh99  defensive_lineman         5.04
# 2276  NaN     Orion Martin\MartOr99  defensive_lineman         4.70
# 2278  NaN       Mitch King\KingMi99  defensive_lineman         4.81
# ...   ...                       ...                ...          ...
# 3355  NaN              Dashawn Hand  defensive_lineman         4.83
# 3358  NaN       John Franklin-Myers  defensive_lineman         4.75
# 3361  NaN            Foley Fatukasi  defensive_lineman         5.29
# 3364  NaN            Matt Dickerson  defensive_lineman         5.06
# 3380  NaN               John Atkins  defensive_lineman         5.38
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 2258          95.25              24.0      292.10           7.31     4.41
# ...

# %%
undrafted_dl_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   131.000000     110.000000        109.000000  109.000000
# mean      5.026336      76.107636         24.385321  273.224771
# std       0.195536       8.695132          4.502897   17.442042
# min       4.630000      52.070000         14.000000  226.060000
# 25%       4.900000      71.120000         21.000000  264.160000
# 50%       4.990000      76.200000         24.000000  274.320000
# 75%       5.160000      81.280000         27.000000  284.480000
# max       5.540000      96.520000         36.000000  312.420000
#
#        Agility_3cone     Shuttle
# count      97.000000  100.000000
# mean        7.540103    4.606000
# std         0.328086    0.210579
# min         6.800000    4.180000
# 25%         7.310000    4.455000
# 50%         7.530000    4.620000
# 75%         7.780000    4.750000
# max         8.260000    5.270000

# %%
undrafted_dl_df.to_csv('Undrafted Defensive Lineman Stats')

# %%
#creating linebacker df - undrafted
undrafted_LB_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'line_backer']
undrafted_LB_df
# Out:
#      Year                      Player Position_Type  Sprint_40yd  \
# 2265  NaN       Lee Robinson\RobiLe99   line_backer         4.71
# 2274  NaN         Josh Mauga\MaugJo00   line_backer         4.61
# 2284  NaN         Mortty Ivy\IvyxMo99   line_backer         4.78
# 2295  NaN    Dannell Ellerbe\ElleDa99   line_backer         4.63
# 2303  NaN  Jonathan Casillas\CasiJo99   line_backer         4.50
# ...   ...                         ...           ...          ...
# 3278  NaN         Skai Moore\MoorSk00   line_backer         4.73
# 3282  NaN        Mike McCray\McCrMi01   line_backer         4.76
# 3298  NaN      Jason Cabinda\CabiJa00   line_backer          NaN
# 3329  NaN                  Jacob Pugh   line_backer         4.65
# 3365  NaN                 Nick Deluca   line_backer         4.85
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 2265          82.55              24.0      287.02           7.57     4.67
# ...

# %%
undrafted_dl_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count   131.000000     110.000000        109.000000  109.000000
# mean      5.026336      76.107636         24.385321  273.224771
# std       0.195536       8.695132          4.502897   17.442042
# min       4.630000      52.070000         14.000000  226.060000
# 25%       4.900000      71.120000         21.000000  264.160000
# 50%       4.990000      76.200000         24.000000  274.320000
# 75%       5.160000      81.280000         27.000000  284.480000
# max       5.540000      96.520000         36.000000  312.420000
#
#        Agility_3cone     Shuttle
# count      97.000000  100.000000
# mean        7.540103    4.606000
# std         0.328086    0.210579
# min         6.800000    4.180000
# 25%         7.310000    4.455000
# 50%         7.530000    4.620000
# 75%         7.780000    4.750000
# max         8.260000    5.270000

# %%
undrafted_dl_df.to_csv('Undrafted Linebacker Stats')

# %%
#creating kicking specialist df - undrafted
undrafted_kicker_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'kicking_specialist']
undrafted_kicker_df
# Out:
#      Year                     Player       Position_Type  Sprint_40yd  \
# 2275  NaN       Tim Masthay\MastTi99  kicking_specialist         4.80
# 2290  NaN       Graham Gano\GanoGr44  kicking_specialist          NaN
# 2302  NaN  Britton Colquitt\ColqBr00  kicking_specialist         4.89
# 2321  NaN                  Sam Swank  kicking_specialist         4.95
# 2323  NaN               Louie Sakoda  kicking_specialist         4.82
# ...   ...                        ...                 ...          ...
# 3368  NaN              Trevor Daniel  kicking_specialist         4.98
# 3377  NaN                 Drew Brown  kicking_specialist          NaN
# 3379  NaN               Mike Badgley  kicking_specialist         4.94
# 3390  NaN        Cole Tracy\TracCo00  kicking_specialist          NaN
# 3431  NaN          Jack Fox\FoxxJa00  kicking_specialist         4.73
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# ...

# %%
undrafted_kicker_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count    66.000000       5.000000          7.000000    5.000000
# mean      4.939394      76.200000         14.285714  286.004000
# std       0.134449       7.880143          5.089672   10.254808
# min       4.610000      68.580000          8.000000  276.860000
# 25%       4.850000      69.850000         11.500000  279.400000
# 50%       4.930000      73.660000         13.000000  281.940000
# 75%       5.050000      82.550000         16.500000  289.560000
# max       5.250000      86.360000         23.000000  302.260000
#
#        Agility_3cone  Shuttle
# count            0.0      0.0
# mean             NaN      NaN
# std              NaN      NaN
# min              NaN      NaN
# 25%              NaN      NaN
# 50%              NaN      NaN
# 75%              NaN      NaN
# max              NaN      NaN

# %%
undrafted_kicker_df.to_csv('Undrafted Kicker Stats')

# %%
# creating other specials df - undrafted
undrafted_other_specialist_df = players_undrafted_df[players_undrafted_df['Position_Type'] == 'other_special']
undrafted_other_specialist_df
# Out:
#      Year                       Player  Position_Type  Sprint_40yd  \
# 2347  NaN                 Sean Griffin  other_special         5.08
# 2413  NaN       Clint Gresham\GresCl00  other_special         5.08
# 2559  NaN         Danny Aiken\AikeDa00  other_special         5.00
# 2636  NaN         Josh Harris\HarrJo02  other_special         4.82
# 2805  NaN                  Luke Ingram  other_special         5.05
# 2921  NaN                  Marcus Heit  other_special         4.91
# 3191  NaN  Bradley Northnagel\NortBr01  other_special         5.30
# 3374  NaN                 Tanner Carew  other_special         5.00
# 3429  NaN          Dan Godsil\GodsDa00  other_special         5.00
#
#       Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  Shuttle
# 2347            NaN              14.0         NaN            NaN      NaN
# 2413            NaN               NaN         NaN            NaN      NaN
# 2559            NaN              11.0         NaN            NaN      NaN
# ...

# %%
undrafted_other_specialist_df.describe()
# Out:
#        Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  \
# count     9.000000       4.000000          6.000000    5.000000
# mean      5.026667      75.565000         16.333333  278.892000
# std       0.132004       9.418572          4.412105   19.126048
# min       4.820000      64.770000         11.000000  251.460000
# 25%       5.000000      71.437500         14.250000  269.240000
# 50%       5.000000      74.930000         15.500000  281.940000
# 75%       5.080000      79.057500         17.500000  292.100000
# max       5.300000      87.630000         24.000000  299.720000
#
#        Agility_3cone   Shuttle
# count       2.000000  2.000000
# mean        7.410000  4.415000
# std         0.212132  0.190919
# min         7.260000  4.280000
# 25%         7.335000  4.347500
# 50%         7.410000  4.415000
# 75%         7.485000  4.482500
# max         7.560000  4.550000

# %%
undrafted_other_specialist_df.to_csv('Undrafted Other Specialist Stats')

# %%
#Bring back original draft_df for new analysis
draft_df = draft_df[draft_df.Drafted == 'Yes']
draft_df
# Out:
# Empty DataFrame
# Columns: [Round, Overall_Pick, Year, Player, Sprint_40yd, Vertical_Jump, Bench_Press_Reps, Broad_Jump, Agility_3cone, Shuttle, Position_Type, Drafted]
# Index: []

# %%
#WSH_df = team_df[team_df['Team'].str.contains('Washington Redskins')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_r/0j0sqst14wj0bs0fnv6b9x840000gn/T/ipykernel_18470/1199257881.py in <module>
#       1 #WSH_df = team_df[team_df['Team'].str.contains('Washington Redskins')]
# ----> 2 one_round_df= draft_df[draft_df['Round'].contains('1st')]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'contains'
